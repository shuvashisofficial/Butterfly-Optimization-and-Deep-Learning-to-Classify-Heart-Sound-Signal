# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import pydot
import kymatio
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from termcolor import colored
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.figure_factory as ff
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score
from kymatio import Scattering1D
import librosa
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Activation, Input, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
#import tensorflow_io as tfio

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.5)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))
tf.compat.v1.keras.backend.set_session(sess)

# %%
epochs = 20

model_file_path = "best_model_file.hdf5"
checkpoint = ModelCheckpoint(model_file_path, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=5,  # <-- Corrected value
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=5,
                              verbose=1,
                              min_delta=0.0001)

csv_logger = tf.keras.callbacks.CSVLogger('Model.log')

# Define a learning rate schedule
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate,
    decay_steps=10000,
    end_learning_rate=0.000001,
    power=0.5,
    cycle=False
)


callbacks = [earlystop, csv_logger, reduce_lr, checkpoint]

# %%
os.listdir(r'D:\MIET_HeartSound\Dataset\Dataset2\heart_sound')
data = os.path.join(r'D:\MIET_HeartSound\Dataset\Dataset2\heart_sound')
data
# Out:
# 'D:\\MIET_HeartSound\\Dataset\\Dataset2\\heart_sound'

# %%
train_dir_path = os.path.join(data, 'train')
valid_dir_path = os.path.join(data, 'val')

# %%
healthy = os.path.join(train_dir_path, 'healthy', 'a0007.wav')
unhealthy = os.path.join(train_dir_path, 'unhealthy', 'a0002.wav')

# %%
def load_wav_16k_mono(filename):
    # Load encoded wav file
    file_contents = tf.io.read_file(filename)
    # Decode wav (tensors by channels)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    print(wav, sample_rate)
    # Removes trailing axis
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    print(wav, sample_rate)
    
    # Goes from 44100Hz to 16000hz - amplitude of the audio signal
#     wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %%
healthy_heart_train = tf.data.Dataset.list_files(train_dir_path+'/healthy'+'/*.wav')
unhealthy_heart_train = tf.data.Dataset.list_files(train_dir_path+'/unhealthy'+'/*.wav')
#healthy_heart_valid = tf.data.Dataset.list_files(valid_dir_path+'/healthy'+'/*.wav')
#unhealthy_heart_valid = tf.data.Dataset.list_files(valid_dir_path+'/unhealthy'+'/*.wav')

# %%
hhl_train = tf.data.Dataset.zip((healthy_heart_train, tf.data.Dataset.from_tensor_slices(tf.ones(len(healthy_heart_train)))))
uhl_train = tf.data.Dataset.zip((unhealthy_heart_train, tf.data.Dataset.from_tensor_slices(tf.zeros(len(unhealthy_heart_train)))))
train_data = hhl_train.concatenate(uhl_train)

#hhl_valid = tf.data.Dataset.zip((healthy_heart_valid, tf.data.Dataset.from_tensor_slices(tf.ones(len(healthy_heart_valid)))))
#uhl_valid = tf.data.Dataset.zip((unhealthy_heart_valid, tf.data.Dataset.from_tensor_slices(tf.zeros(len(unhealthy_heart_valid)))))
#valid_data = hhl_valid.concatenate(uhl_valid)

# %%
# Calculate the lengths
train_length = tf.data.experimental.cardinality(train_data).numpy()
#valid_length = tf.data.experimental.cardinality(valid_data).numpy()

# Print the lengths
print("Length of train_data:", train_length)
#print("Length of valid_data:", valid_length)
# Out:
# Length of train_data: 3240

# %%
def extract_mfcc(file_path, label, wav_length=30000):
    def mfccs(wav):
        # Ensure wav is a numpy array
        wav = wav.numpy()
        
        mfcc = librosa.feature.mfcc(y=wav, sr=2000, n_mfcc=7)
        return mfcc

    wav = load_wav_16k_mono(file_path)
    wav = tf.cast(wav, dtype=tf.float32)  # Ensure wav is float32
    wav = wav / tf.reduce_max(tf.abs(wav))
    wav = wav[:wav_length] if tf.shape(wav)[0] > wav_length else tf.pad(wav, [(0, wav_length - tf.shape(wav)[0])], "CONSTANT")

    # Using tf.py_function to wrap the scattering transform
    mfcc = tf.py_function(mfccs, [wav], tf.float32)
    mfcc = tf.abs(mfcc)
    # You might need to set the shape of the output manually if required
    #scattering_transform.set_shape((7, 157))  # Set the correct shape based on your scattering output
    mfcc = tf.expand_dims(mfcc, axis=2)
    print('scattering_transform',mfcc.shape, type(mfcc))
    return mfcc, label

# %%
iterator = hhl_train.shuffle(buffer_size=10000).as_numpy_iterator()
iterator.next()
filepath, label = next(iterator)
print(filepath, label)
# Out:
# b'D:\\MIET_HeartSound\\Dataset\\Dataset2\\heart_sound\\train\\healthy\\e00499.wav' 1.0

# %%
mfcc, label = extract_mfcc(filepath, label)
print(mfcc.shape)
# Out:
# tf.Tensor(
# [[0.0135498 ]
#  [0.01898193]
#  [0.01898193]
#  ...
#  [0.03253174]
#  [0.04064941]
#  [0.03253174]], shape=(38186, 1), dtype=float32) tf.Tensor(2000, shape=(), dtype=int32)
# tf.Tensor([0.0135498  0.01898193 0.01898193 ... 0.03253174 0.04064941 0.03253174], shape=(38186,), dtype=float32) tf.Tensor(2000, shape=(), dtype=int64)
# scattering_transform (7, 59, 1) <class 'tensorflow.python.framework.ops.EagerTensor'>
# (7, 59, 1)

# %%
train_data = train_data.map(extract_mfcc)
train_data = train_data.cache()
train_data = train_data.shuffle(buffer_size=1000)
train_data = train_data.batch(4)
train_data = train_data.prefetch(2)
# Out:
# Tensor("DecodeWav:0", shape=(None, 1), dtype=float32) Tensor("DecodeWav:1", shape=(), dtype=int32)
# Tensor("Squeeze:0", shape=(None,), dtype=float32) Tensor("Cast:0", shape=(), dtype=int64)
# scattering_transform <unknown> <class 'tensorflow.python.framework.ops.Tensor'>

# %%
num_samples = tf.data.experimental.cardinality(train_data).numpy()
print(f"Number of samples in train_data: {num_samples}")
# Out:
# Number of samples in train_data: 810

# %%
import tensorflow as tf

# Assuming train_data is your complete dataset
total_samples = len(list(train_data.as_numpy_iterator()))  # Get the total number of samples in the dataset

# Define split proportions
train_size = int(total_samples * 0.7)
val_size = int(total_samples * 0.20)
test_size = total_samples - train_size - val_size  # Ensures all data is used and accounts for rounding

# Create the datasets
train = train_data.take(train_size)
val = train_data.skip(train_size).take(val_size)
test = train_data.skip(train_size + val_size)

# Example of extracting a batch from the train dataset to check shapes
samples, labels = next(iter(train.batch(1)))
print("Sample shape:", samples.shape)
print("Labels:", labels)

# This gives you three datasets: train, val, and test
# You can iterate over these datasets as needed for training and evaluation
# Out:
# Sample shape: (1, 4, 7, 59, 1)
# Labels: tf.Tensor([[1. 1. 1. 1.]], shape=(1, 4), dtype=float32)

# %%
# Calculate the lengths
train_length = tf.data.experimental.cardinality(train).numpy()
val_length = tf.data.experimental.cardinality(val).numpy()
test_length = tf.data.experimental.cardinality(test).numpy()

# Print the lengths
print("Length of train:", train_length)
print("Length of validation:", val_length)
print("Length of test:", test_length)
# Out:
# Length of train: 567
# Length of validation: 162
# Length of test: 81

# %% [markdown]
# CNN

# %%
def cnn():
    model = Sequential()
    model.add(Conv2D(16, (2,2), activation='relu', input_shape=(7, 59, 1)))
    model.add(Conv2D(32, (2,2), activation='relu'))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
# Create an optimizer with the learning rate schedule
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model0 = cnn()
model0.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
model0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 6, 58, 16)         80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 57, 32)         2080
# _________________________________________________________________
# flatten (Flatten)            (None, 9120)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1167488
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,169,777
# Trainable params: 1,169,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
#tf.keras.utils.plot_model(model0, 
           #show_shapes = True,
          # show_dtype= True,
           #show_layer_names = True,
           #show_layer_activations= True,
           #rankdir = 'TB', 
           #expand_nested = False, 
           #dpi = 70)

# %%
batch_size = 16

history0 = model0.fit(train, 
                    batch_size=batch_size, 
                    epochs=30,
                    validation_data=test,
                    verbose=1,
                    )
# Out:
# Epoch 1/30
# 567/567 [==============================] - 10s 4ms/step - loss: 0.3790 - accuracy: 0.9127 - val_loss: 0.4659 - val_accuracy: 0.8025
# Epoch 2/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.1779 - accuracy: 0.9405 - val_loss: 0.4460 - val_accuracy: 0.8025
# Epoch 3/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.1180 - accuracy: 0.9541 - val_loss: 0.5731 - val_accuracy: 0.7160
# Epoch 4/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0992 - accuracy: 0.9594 - val_loss: 0.3248 - val_accuracy: 0.8735
# Epoch 5/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0922 - accuracy: 0.9621 - val_loss: 0.3579 - val_accuracy: 0.8333
# Epoch 6/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0915 - accuracy: 0.9590 - val_loss: 0.3803 - val_accuracy: 0.8333
# Epoch 7/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0844 - accuracy: 0.9696 - val_loss: 0.3365 - val_accuracy: 0.8488
# Epoch 8/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0722 - accuracy: 0.9744 - val_loss: 0.2504 - val_accuracy: 0.8951
# Epoch 9/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0787 - accuracy: 0.9718 - val_loss: 0.2913 - val_accuracy: 0.8827
# Epoch 10/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0610 - accuracy: 0.9757 - val_loss: 0.2128 - val_accuracy: 0.9105
# Epoch 11/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0632 - accuracy: 0.9757 - val_loss: 0.2921 - val_accuracy: 0.8642
# Epoch 12/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0665 - accuracy: 0.9784 - val_loss: 0.1881 - val_accuracy: 0.9228
# Epoch 13/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0622 - accuracy: 0.9771 - val_loss: 0.1659 - val_accuracy: 0.9167
# Epoch 14/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0444 - accuracy: 0.9806 - val_loss: 0.2402 - val_accuracy: 0.8858
# Epoch 15/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0467 - accuracy: 0.9806 - val_loss: 0.2208 - val_accuracy: 0.9012
# Epoch 16/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0458 - accuracy: 0.9846 - val_loss: 0.1621 - val_accuracy: 0.9198
# Epoch 17/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0515 - accuracy: 0.9806 - val_loss: 0.2057 - val_accuracy: 0.9198
# Epoch 18/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0400 - accuracy: 0.9841 - val_loss: 0.1963 - val_accuracy: 0.9228
# Epoch 19/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0343 - accuracy: 0.9868 - val_loss: 0.1800 - val_accuracy: 0.9105
# Epoch 20/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.1548 - val_accuracy: 0.9383
# Epoch 21/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0354 - accuracy: 0.9854 - val_loss: 0.1536 - val_accuracy: 0.9321
# Epoch 22/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0269 - accuracy: 0.9885 - val_loss: 0.1100 - val_accuracy: 0.9599
# Epoch 23/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0215 - accuracy: 0.9899 - val_loss: 0.0945 - val_accuracy: 0.9660
# Epoch 24/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 0.1211 - val_accuracy: 0.9537
# Epoch 25/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0243 - accuracy: 0.9907 - val_loss: 0.1045 - val_accuracy: 0.9568
# Epoch 26/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0209 - accuracy: 0.9921 - val_loss: 0.1918 - val_accuracy: 0.9321
# Epoch 27/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.1050 - val_accuracy: 0.9660
# Epoch 28/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0171 - accuracy: 0.9929 - val_loss: 0.0832 - val_accuracy: 0.9660
# Epoch 29/30
# 567/567 [==============================] - 2s 4ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.0951 - val_accuracy: 0.9599
# Epoch 30/30
# 567/567 [==============================] - 2s 3ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.0999 - val_accuracy: 0.9630

# %%
model0.save("Model-mfcc-dummy1.h5")
print('Model save to Disk')
# Out:
# Model save to Disk

# %%
df = pd.DataFrame(history0.history) 
#df.to_excel("output.xlsx")
#df.to_csv("output.csv")
df.head(50)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.379034  0.912698  0.465886      0.802469
# 1   0.177917  0.940476  0.445978      0.802469
# 2   0.117999  0.954145  0.573127      0.716049
# 3   0.099191  0.959436  0.324798      0.873457
# 4   0.092224  0.962081  0.357864      0.833333
# 5   0.091501  0.958995  0.380316      0.833333
# 6   0.084365  0.969577  0.336487      0.848765
# 7   0.072239  0.974427  0.250441      0.895062
# 8   0.078664  0.971781  0.291343      0.882716
# 9   0.060965  0.975750  0.212815      0.910494
# 10  0.063191  0.975750  0.292092      0.864198
# 11  0.066470  0.978395  0.188092      0.922840
# 12  0.062161  0.977072  0.165851      0.916667
# 13  0.044386  0.980600  0.240202      0.885802
# 14  0.046687  0.980600  0.220788      0.901235
# 15  0.045797  0.984568  0.162103      0.919753
# 16  0.051531  0.980600  0.205672      0.919753
# 17  0.039991  0.984127  0.196258      0.922840
# 18  0.034302  0.986772  0.179989      0.910494
# 19  0.032070  0.988977  0.154813      0.938272
# 20  0.035414  0.985450  0.153599      0.932099
# 21  0.026929  0.988536  0.109953      0.959877
# 22  0.021540  0.989859  0.094540      0.966049
# 23  0.019241  0.993386  0.121072      0.953704
# 24  0.024280  0.990741  0.104509      0.956790
# 25  0.020911  0.992063  0.191843      0.932099
# 26  0.021022  0.993827  0.105050      0.966049
# 27  0.017053  0.992945  0.083219      0.966049
# 28  0.014680  0.995591  0.095058      0.959877
# 29  0.014734  0.996032  0.099906      0.962963

# %%
# Interpreting the Metrics
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss' ]):
    ax[i].plot(history0.history[met])
    ax[i].plot(history0.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
plt.savefig("Model0-Results.png")

# %%
# %%time
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results0 = model0.evaluate(test)
print("test loss, test acc:", results0)
# Out:
# Evaluate on test data
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9568
# test loss, test acc: [0.11608217656612396, 0.9567901492118835]
# Wall time: 205 ms

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Step 4: Make predictions and evaluate on the test set
true_labels = []
predicted_labels = []

for samples, labels in test.as_numpy_iterator():
    predictions = model0.predict(samples)
    predicted_classes = (predictions > 0.5).astype(int)  # Adjust threshold as needed
    true_labels.extend(labels)
    predicted_labels.extend(predicted_classes)

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Step 5: Classification report and confusion matrix
print(classification_report(true_labels, predicted_labels))
cm = confusion_matrix(true_labels, predicted_labels)
print(cm)

# Plot the confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96       160
#          1.0       1.00      0.92      0.96       164
#
#     accuracy                           0.96       324
#    macro avg       0.96      0.96      0.96       324
# weighted avg       0.96      0.96      0.96       324
#
# [[160   0]
#  [ 13 151]]

# %% [markdown]
# BiLSTM

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the model architecture
model2 = models.Sequential([
    # Since the input includes a singleton dimension, you can use a Lambda layer to remove it
    layers.Lambda(lambda x: tf.squeeze(x, axis=-1), input_shape=(7, 59, 1)),
    # First BiLSTM layer, return sequences to pass to another LSTM layer
    layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
    # Second BiLSTM layer, no need to return sequences as this is the final LSTM layer
    layers.Bidirectional(layers.LSTM(32)),
    # Dense layer for interpretation
    layers.Dense(64, activation='relu'),
    # Dropout for regularization
    layers.Dropout(0.5),
    # Output layer
    layers.Dense(1, activation='sigmoid')
])

# %%
# Create an optimizer with the learning rate schedule
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model2.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 7, 59)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 7, 128)            63488
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 108,929
# Trainable params: 108,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(train_data, epochs=50, verbose=1, validation_data=val,batch_size=16)
# Out:
# Epoch 1/50
# 810/810 [==============================] - 13s 12ms/step - loss: 0.4252 - accuracy: 0.7901 - val_loss: 0.6576 - val_accuracy: 0.6435
# Epoch 2/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.3912 - accuracy: 0.8123 - val_loss: 0.6489 - val_accuracy: 0.6080
# Epoch 3/50
# 810/810 [==============================] - 9s 12ms/step - loss: 0.3631 - accuracy: 0.8287 - val_loss: 0.6054 - val_accuracy: 0.7191
# Epoch 4/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.3444 - accuracy: 0.8506 - val_loss: 0.5460 - val_accuracy: 0.7222
# Epoch 5/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.3062 - accuracy: 0.8682 - val_loss: 0.4924 - val_accuracy: 0.7670
# Epoch 6/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.2874 - accuracy: 0.8799 - val_loss: 0.5163 - val_accuracy: 0.7191
# Epoch 7/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.2754 - accuracy: 0.8864 - val_loss: 0.4436 - val_accuracy: 0.7917
# Epoch 8/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.2709 - accuracy: 0.8833 - val_loss: 0.4882 - val_accuracy: 0.7377
# Epoch 9/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.2452 - accuracy: 0.8957 - val_loss: 0.4149 - val_accuracy: 0.8071
# Epoch 10/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.2465 - accuracy: 0.8963 - val_loss: 0.4007 - val_accuracy: 0.8040
# Epoch 11/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.2310 - accuracy: 0.9090 - val_loss: 0.3767 - val_accuracy: 0.8380
# Epoch 12/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.2329 - accuracy: 0.8975 - val_loss: 0.3572 - val_accuracy: 0.8457
# Epoch 13/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.2226 - accuracy: 0.9046 - val_loss: 0.3569 - val_accuracy: 0.8488
# Epoch 14/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.2100 - accuracy: 0.9133 - val_loss: 0.3280 - val_accuracy: 0.8549
# Epoch 15/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.2035 - accuracy: 0.9136 - val_loss: 0.3392 - val_accuracy: 0.8488
# Epoch 16/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1963 - accuracy: 0.9170 - val_loss: 0.3014 - val_accuracy: 0.8765
# Epoch 17/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1969 - accuracy: 0.9167 - val_loss: 0.2913 - val_accuracy: 0.8873
# Epoch 18/50
# 810/810 [==============================] - 9s 12ms/step - loss: 0.1956 - accuracy: 0.9154 - val_loss: 0.3088 - val_accuracy: 0.8611
# Epoch 19/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1814 - accuracy: 0.9213 - val_loss: 0.3132 - val_accuracy: 0.8704
# Epoch 20/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1759 - accuracy: 0.9272 - val_loss: 0.3147 - val_accuracy: 0.8596
# Epoch 21/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1703 - accuracy: 0.9336 - val_loss: 0.3021 - val_accuracy: 0.8611
# Epoch 22/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1697 - accuracy: 0.9324 - val_loss: 0.3178 - val_accuracy: 0.8657
# Epoch 23/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1676 - accuracy: 0.9296 - val_loss: 0.2584 - val_accuracy: 0.8827
# Epoch 24/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1463 - accuracy: 0.9441 - val_loss: 0.2488 - val_accuracy: 0.9012
# Epoch 25/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.1602 - accuracy: 0.9361 - val_loss: 0.3575 - val_accuracy: 0.8565
# Epoch 26/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1551 - accuracy: 0.9401 - val_loss: 0.2350 - val_accuracy: 0.9120
# Epoch 27/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1436 - accuracy: 0.9417 - val_loss: 0.2051 - val_accuracy: 0.9167
# Epoch 28/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1463 - accuracy: 0.9429 - val_loss: 0.2528 - val_accuracy: 0.8951
# Epoch 29/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1373 - accuracy: 0.9475 - val_loss: 0.1936 - val_accuracy: 0.9321
# Epoch 30/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1271 - accuracy: 0.9519 - val_loss: 0.1966 - val_accuracy: 0.9290
# Epoch 31/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1275 - accuracy: 0.9506 - val_loss: 0.2371 - val_accuracy: 0.9012
# Epoch 32/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1203 - accuracy: 0.9568 - val_loss: 0.1863 - val_accuracy: 0.9275
# Epoch 33/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1120 - accuracy: 0.9599 - val_loss: 0.1976 - val_accuracy: 0.9228
# Epoch 34/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1281 - accuracy: 0.9522 - val_loss: 0.1783 - val_accuracy: 0.9259
# Epoch 35/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.1273 - accuracy: 0.9491 - val_loss: 0.1449 - val_accuracy: 0.9599
# Epoch 36/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1118 - accuracy: 0.9586 - val_loss: 0.1838 - val_accuracy: 0.9228
# Epoch 37/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1058 - accuracy: 0.9627 - val_loss: 0.1510 - val_accuracy: 0.9475
# Epoch 38/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1004 - accuracy: 0.9630 - val_loss: 0.1655 - val_accuracy: 0.9306
# Epoch 39/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.1046 - accuracy: 0.9639 - val_loss: 0.1227 - val_accuracy: 0.9506
# Epoch 40/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.1016 - accuracy: 0.9611 - val_loss: 0.1340 - val_accuracy: 0.9491
# Epoch 41/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0955 - accuracy: 0.9642 - val_loss: 0.1272 - val_accuracy: 0.9552
# Epoch 42/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0945 - accuracy: 0.9670 - val_loss: 0.1778 - val_accuracy: 0.9213
# Epoch 43/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0908 - accuracy: 0.9642 - val_loss: 0.1304 - val_accuracy: 0.9475
# Epoch 44/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0831 - accuracy: 0.9673 - val_loss: 0.1184 - val_accuracy: 0.9614
# Epoch 45/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0877 - accuracy: 0.9688 - val_loss: 0.1847 - val_accuracy: 0.9275
# Epoch 46/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0788 - accuracy: 0.9704 - val_loss: 0.1646 - val_accuracy: 0.9321
# Epoch 47/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.0825 - accuracy: 0.9682 - val_loss: 0.0893 - val_accuracy: 0.9691
# Epoch 48/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0880 - accuracy: 0.9679 - val_loss: 0.1523 - val_accuracy: 0.9429
# Epoch 49/50
# 810/810 [==============================] - 8s 10ms/step - loss: 0.0789 - accuracy: 0.9728 - val_loss: 0.3121 - val_accuracy: 0.8735
# Epoch 50/50
# 810/810 [==============================] - 9s 11ms/step - loss: 0.0754 - accuracy: 0.9731 - val_loss: 0.1029 - val_accuracy: 0.9583

# %%
model2.save("Model-Mfcc-bilstm-dummy1.h5")
print('Model save to Disk')
# Out:
# Model save to Disk

# %%
df = pd.DataFrame(history2.history) 
#df.to_excel("output.xlsx")
#df.to_csv("output.csv")
df.head(50)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.425198  0.790123  0.657595      0.643519
# 1   0.391215  0.812346  0.648917      0.608025
# 2   0.363110  0.828704  0.605379      0.719136
# 3   0.344442  0.850617  0.545959      0.722222
# 4   0.306244  0.868210  0.492434      0.766975
# 5   0.287398  0.879938  0.516286      0.719136
# 6   0.275371  0.886420  0.443562      0.791667
# 7   0.270938  0.883333  0.488244      0.737654
# 8   0.245192  0.895679  0.414859      0.807099
# 9   0.246550  0.896296  0.400698      0.804012
# 10  0.231008  0.908951  0.376665      0.837963
# 11  0.232908  0.897531  0.357153      0.845679
# 12  0.222612  0.904630  0.356930      0.848765
# 13  0.209989  0.913272  0.328014      0.854938
# 14  0.203541  0.913580  0.339193      0.848765
# 15  0.196285  0.916975  0.301420      0.876543
# 16  0.196907  0.916667  0.291336      0.887346
# 17  0.195575  0.915432  0.308818      0.861111
# 18  0.181432  0.921296  0.313155      0.870370
# 19  0.175943  0.927161  0.314656      0.859568
# 20  0.170326  0.933642  0.302107      0.861111
# 21  0.169743  0.932407  0.317784      0.865741
# 22  0.167616  0.929630  0.258354      0.882716
# 23  0.146294  0.944136  0.248786      0.901235
# 24  0.160177  0.936111  0.357497      0.856481
# 25  0.155134  0.940123  0.235032      0.912037
# 26  0.143603  0.941667  0.205068      0.916667
# 27  0.146337  0.942901  0.252839      0.895062
# 28  0.137262  0.947531  0.193600      0.932099
# 29  0.127094  0.951852  0.196593      0.929012
# 30  0.127518  0.950617  0.237074      0.901235
# 31  0.120266  0.956790  0.186323      0.927469
# 32  0.112045  0.959877  0.197604      0.922840
# 33  0.128108  0.952160  0.178329      0.925926
# 34  0.127254  0.949074  0.144926      0.959877
# 35  0.111795  0.958642  0.183751      0.922840
# 36  0.105839  0.962654  0.151044      0.947531
# 37  0.100419  0.962963  0.165482      0.930556
# 38  0.104585  0.963889  0.122706      0.950617
# 39  0.101601  0.961111  0.133990      0.949074
# 40  0.095500  0.964198  0.127206      0.955247
# 41  0.094535  0.966975  0.177835      0.921296
# 42  0.090805  0.964198  0.130374      0.947531
# 43  0.083080  0.967284  0.118387      0.961420
# 44  0.087702  0.968827  0.184698      0.927469
# 45  0.078830  0.970370  0.164623      0.932099
# 46  0.082489  0.968210  0.089314      0.969136
# 47  0.088034  0.967901  0.152342      0.942901
# 48  0.078879  0.972840  0.312058      0.873457
# 49  0.075385  0.973148  0.102927      0.958333

# %%
# Interpreting the Metrics
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss' ]):
    ax[i].plot(history2.history[met])
    ax[i].plot(history2.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
plt.savefig("Model2-Results.png")

# %%
# %%time
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results0 = model2.evaluate(test)
print("test loss, test acc:", results0)
# Out:
# Evaluate on test data
# 81/81 [==============================] - 0s 5ms/step - loss: 0.1267 - accuracy: 0.9568
# test loss, test acc: [0.12669122219085693, 0.9567901492118835]
# Wall time: 413 ms

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Step 4: Make predictions and evaluate on the test set
true_labels = []
predicted_labels = []

for samples, labels in test.as_numpy_iterator():
    predictions = model2.predict(samples)
    predicted_classes = (predictions > 0.5).astype(int)  # Adjust threshold as needed
    true_labels.extend(labels)
    predicted_labels.extend(predicted_classes)

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Step 5: Classification report and confusion matrix
print(classification_report(true_labels, predicted_labels))
cm = confusion_matrix(true_labels, predicted_labels)
print(cm)

# Plot the confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94       156
#          1.0       0.95      0.94      0.94       168
#
#     accuracy                           0.94       324
#    macro avg       0.94      0.94      0.94       324
# weighted avg       0.94      0.94      0.94       324
#
# [[147   9]
#  [ 10 158]]

# %% [markdown]
# BiRNN

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the model architecture
model3 = models.Sequential([
    # Since the input includes a singleton dimension, you can use a Lambda layer to remove it
    layers.Lambda(lambda x: tf.squeeze(x, axis=-1), input_shape=(7, 59, 1)),
    # First BiLSTM layer, return sequences to pass to another LSTM layer
    layers.Bidirectional(layers.SimpleRNN(64, return_sequences=True)),
    # Second BiLSTM layer, no need to return sequences as this is the final LSTM layer
    layers.Bidirectional(layers.SimpleRNN(32)),
    # Dense layer for interpretation
    layers.Dense(64, activation='relu'),
    # Dropout for regularization
    layers.Dropout(0.5),
    # Output layer
    layers.Dense(1, activation='sigmoid')
])

# %%
# Create an optimizer with the learning rate schedule
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model3.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
model3.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_8 (Lambda)            (None, 7, 59)             0
# _________________________________________________________________
# bidirectional_16 (Bidirectio (None, 7, 128)            15872
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, 64)                10304
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 30,401
# Trainable params: 30,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
history3 = model3.fit(train_data, epochs=50, verbose=1, validation_data=val, batch_size=16)
# Out:
# Epoch 1/50
# 810/810 [==============================] - 25s 29ms/step - loss: 0.4397 - accuracy: 0.7833 - val_loss: 0.6314 - val_accuracy: 0.6466
# Epoch 2/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.3897 - accuracy: 0.8059 - val_loss: 0.6204 - val_accuracy: 0.6682
# Epoch 3/50
# 810/810 [==============================] - 26s 32ms/step - loss: 0.3586 - accuracy: 0.8373 - val_loss: 0.5748 - val_accuracy: 0.7130
# Epoch 4/50
# 810/810 [==============================] - 25s 30ms/step - loss: 0.3404 - accuracy: 0.8398 - val_loss: 0.5583 - val_accuracy: 0.7238
# Epoch 5/50
# 810/810 [==============================] - 22s 27ms/step - loss: 0.3207 - accuracy: 0.8611 - val_loss: 0.5013 - val_accuracy: 0.7562
# Epoch 6/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.3159 - accuracy: 0.8639 - val_loss: 0.5028 - val_accuracy: 0.7392
# Epoch 7/50
# 810/810 [==============================] - 26s 32ms/step - loss: 0.3016 - accuracy: 0.8691 - val_loss: 0.4753 - val_accuracy: 0.7731
# Epoch 8/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.2779 - accuracy: 0.8793 - val_loss: 0.4480 - val_accuracy: 0.7948
# Epoch 9/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.2686 - accuracy: 0.8840 - val_loss: 0.4244 - val_accuracy: 0.8025
# Epoch 10/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.2489 - accuracy: 0.8910 - val_loss: 0.4236 - val_accuracy: 0.8071
# Epoch 11/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.2497 - accuracy: 0.8951 - val_loss: 0.3973 - val_accuracy: 0.8302
# Epoch 12/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.2400 - accuracy: 0.9037 - val_loss: 0.3997 - val_accuracy: 0.8241
# Epoch 13/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.2345 - accuracy: 0.8985 - val_loss: 0.3475 - val_accuracy: 0.8549
# Epoch 14/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.2248 - accuracy: 0.9074 - val_loss: 0.3720 - val_accuracy: 0.8272
# Epoch 15/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.2217 - accuracy: 0.9090 - val_loss: 0.3339 - val_accuracy: 0.8534
# Epoch 16/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.2250 - accuracy: 0.9056 - val_loss: 0.3612 - val_accuracy: 0.8410
# Epoch 17/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.2082 - accuracy: 0.9145 - val_loss: 0.3287 - val_accuracy: 0.8534
# Epoch 18/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.2065 - accuracy: 0.9173 - val_loss: 0.2900 - val_accuracy: 0.8873
# Epoch 19/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.1996 - accuracy: 0.9191 - val_loss: 0.3102 - val_accuracy: 0.8657
# Epoch 20/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.1919 - accuracy: 0.9145 - val_loss: 0.2978 - val_accuracy: 0.8750
# Epoch 21/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.1865 - accuracy: 0.9262 - val_loss: 0.2732 - val_accuracy: 0.8904
# Epoch 22/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.1819 - accuracy: 0.9256 - val_loss: 0.2885 - val_accuracy: 0.8796
# Epoch 23/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.1771 - accuracy: 0.9312 - val_loss: 0.2771 - val_accuracy: 0.8904
# Epoch 24/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.1769 - accuracy: 0.9312 - val_loss: 0.2446 - val_accuracy: 0.9028
# Epoch 25/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.1653 - accuracy: 0.9336 - val_loss: 0.2916 - val_accuracy: 0.8750
# Epoch 26/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.1740 - accuracy: 0.9296 - val_loss: 0.2285 - val_accuracy: 0.9120
# Epoch 27/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.1612 - accuracy: 0.9327 - val_loss: 0.2390 - val_accuracy: 0.9259
# Epoch 28/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.1679 - accuracy: 0.9299 - val_loss: 0.2737 - val_accuracy: 0.8981
# Epoch 29/50
# 810/810 [==============================] - 23s 28ms/step - loss: 0.1567 - accuracy: 0.9392 - val_loss: 0.2500 - val_accuracy: 0.9167
# Epoch 30/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.1487 - accuracy: 0.9417 - val_loss: 0.2177 - val_accuracy: 0.9198
# Epoch 31/50
# 810/810 [==============================] - 25s 30ms/step - loss: 0.1463 - accuracy: 0.9432 - val_loss: 0.2543 - val_accuracy: 0.8951
# Epoch 32/50
# 810/810 [==============================] - 25s 31ms/step - loss: 0.1524 - accuracy: 0.9414 - val_loss: 0.2227 - val_accuracy: 0.9167
# Epoch 33/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.1468 - accuracy: 0.9395 - val_loss: 0.2030 - val_accuracy: 0.9321
# Epoch 34/50
# 810/810 [==============================] - 23s 28ms/step - loss: 0.1325 - accuracy: 0.9485 - val_loss: 0.1956 - val_accuracy: 0.9336
# Epoch 35/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.1354 - accuracy: 0.9488 - val_loss: 0.1824 - val_accuracy: 0.9429
# Epoch 36/50
# 810/810 [==============================] - 25s 31ms/step - loss: 0.1268 - accuracy: 0.9519 - val_loss: 0.1646 - val_accuracy: 0.9352
# Epoch 37/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.1233 - accuracy: 0.9522 - val_loss: 0.1417 - val_accuracy: 0.9552
# Epoch 38/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.1198 - accuracy: 0.9534 - val_loss: 0.1893 - val_accuracy: 0.9321
# Epoch 39/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.1211 - accuracy: 0.9546 - val_loss: 0.1843 - val_accuracy: 0.9182
# Epoch 40/50
# 810/810 [==============================] - 25s 31ms/step - loss: 0.1189 - accuracy: 0.9528 - val_loss: 0.2108 - val_accuracy: 0.9120
# Epoch 41/50
# 810/810 [==============================] - 25s 31ms/step - loss: 0.1225 - accuracy: 0.9491 - val_loss: 0.2010 - val_accuracy: 0.9259
# Epoch 42/50
# 810/810 [==============================] - 23s 28ms/step - loss: 0.1041 - accuracy: 0.9633 - val_loss: 0.1689 - val_accuracy: 0.9444
# Epoch 43/50
# 810/810 [==============================] - 23s 28ms/step - loss: 0.1093 - accuracy: 0.9599 - val_loss: 0.1780 - val_accuracy: 0.9275
# Epoch 44/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.1142 - accuracy: 0.9549 - val_loss: 0.1346 - val_accuracy: 0.9552
# Epoch 45/50
# 810/810 [==============================] - 25s 30ms/step - loss: 0.1054 - accuracy: 0.9599 - val_loss: 0.1591 - val_accuracy: 0.9491
# Epoch 46/50
# 810/810 [==============================] - 24s 30ms/step - loss: 0.1073 - accuracy: 0.9657 - val_loss: 0.1292 - val_accuracy: 0.9660
# Epoch 47/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.0970 - accuracy: 0.9611 - val_loss: 0.1305 - val_accuracy: 0.9599
# Epoch 48/50
# 810/810 [==============================] - 23s 29ms/step - loss: 0.0991 - accuracy: 0.9660 - val_loss: 0.1223 - val_accuracy: 0.9691
# Epoch 49/50
# 810/810 [==============================] - 24s 29ms/step - loss: 0.0912 - accuracy: 0.9667 - val_loss: 0.1270 - val_accuracy: 0.9537
# Epoch 50/50
# 810/810 [==============================] - 25s 31ms/step - loss: 0.1015 - accuracy: 0.9617 - val_loss: 0.1310 - val_accuracy: 0.9537

# %%
model3.save("Model-MFCC-birnn-dummy1.h5")
print('Model save to Disk')
# Out:
# Model save to Disk

# %%
df = pd.DataFrame(history3.history) 
#df.to_excel("output.xlsx")
#df.to_csv("output.csv")
df.head(50)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.439663  0.783333  0.631436      0.646605
# 1   0.389695  0.805864  0.620447      0.668210
# 2   0.358602  0.837346  0.574806      0.712963
# 3   0.340360  0.839815  0.558330      0.723765
# 4   0.320657  0.861111  0.501268      0.756173
# 5   0.315897  0.863889  0.502769      0.739198
# 6   0.301635  0.869136  0.475305      0.773148
# 7   0.277928  0.879321  0.448025      0.794753
# 8   0.268587  0.883951  0.424415      0.802469
# 9   0.248855  0.891049  0.423597      0.807099
# 10  0.249691  0.895062  0.397340      0.830247
# 11  0.239976  0.903704  0.399697      0.824074
# 12  0.234525  0.898457  0.347535      0.854938
# 13  0.224827  0.907407  0.371991      0.827160
# 14  0.221705  0.908951  0.333884      0.853395
# 15  0.224991  0.905556  0.361212      0.841049
# 16  0.208223  0.914506  0.328744      0.853395
# 17  0.206522  0.917284  0.290039      0.887346
# 18  0.199608  0.919136  0.310234      0.865741
# 19  0.191921  0.914506  0.297847      0.875000
# 20  0.186490  0.926235  0.273237      0.890432
# 21  0.181893  0.925617  0.288484      0.879630
# 22  0.177065  0.931173  0.277124      0.890432
# 23  0.176868  0.931173  0.244592      0.902778
# 24  0.165267  0.933642  0.291560      0.875000
# 25  0.173997  0.929630  0.228533      0.912037
# 26  0.161171  0.932716  0.238955      0.925926
# 27  0.167884  0.929938  0.273674      0.898148
# 28  0.156664  0.939198  0.250006      0.916667
# 29  0.148745  0.941667  0.217711      0.919753
# 30  0.146281  0.943210  0.254252      0.895062
# 31  0.152371  0.941358  0.222669      0.916667
# 32  0.146786  0.939506  0.203022      0.932099
# 33  0.132500  0.948457  0.195622      0.933642
# 34  0.135424  0.948765  0.182387      0.942901
# 35  0.126767  0.951852  0.164648      0.935185
# 36  0.123309  0.952160  0.141749      0.955247
# 37  0.119840  0.953395  0.189260      0.932099
# 38  0.121128  0.954630  0.184344      0.918210
# 39  0.118870  0.952778  0.210843      0.912037
# 40  0.122507  0.949074  0.200961      0.925926
# 41  0.104066  0.963272  0.168942      0.944444
# 42  0.109311  0.959877  0.177984      0.927469
# 43  0.114240  0.954938  0.134558      0.955247
# 44  0.105423  0.959877  0.159102      0.949074
# 45  0.107295  0.965741  0.129200      0.966049
# 46  0.096974  0.961111  0.130500      0.959877
# 47  0.099121  0.966049  0.122318      0.969136
# 48  0.091244  0.966667  0.126965      0.953704
# 49  0.101533  0.961728  0.131029      0.953704

# %%
# Interpreting the Metrics
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss' ]):
    ax[i].plot(history3.history[met])
    ax[i].plot(history3.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
plt.savefig("Model3-Results.png")

# %%
# %%time
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results0 = model3.evaluate(test)
print("test loss, test acc:", results0)
# Out:
# Evaluate on test data
# 81/81 [==============================] - 1s 7ms/step - loss: 0.1216 - accuracy: 0.9506
# test loss, test acc: [0.12160608172416687, 0.9506173133850098]
# Wall time: 580 ms

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Step 4: Make predictions and evaluate on the test set
true_labels = []
predicted_labels = []

for samples, labels in test.as_numpy_iterator():
    predictions = model3.predict(samples)
    predicted_classes = (predictions > 0.5).astype(int)  # Adjust threshold as needed
    true_labels.extend(labels)
    predicted_labels.extend(predicted_classes)

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Step 5: Classification report and confusion matrix
print(classification_report(true_labels, predicted_labels))
cm = confusion_matrix(true_labels, predicted_labels)
print(cm)

# Plot the confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96       175
#          1.0       0.99      0.91      0.95       149
#
#     accuracy                           0.95       324
#    macro avg       0.96      0.95      0.95       324
# weighted avg       0.96      0.95      0.95       324
#
# [[173   2]
#  [ 13 136]]

# %% [markdown]
# SVM

# %%
import numpy as np

def preprocess_dataset(dataset):
    # Flatten each sample and collect them
    all_samples = []
    all_labels = []

    for samples, labels in dataset.as_numpy_iterator():
        # Flatten from (4, 7, 469, 1) to (4, 7*469)
        samples_flattened = samples.reshape(samples.shape[0], -1)
        all_samples.append(samples_flattened)
        all_labels.append(labels)

    # Convert lists to numpy arrays
    all_samples = np.vstack(all_samples)  # Stack arrays vertically
    all_labels = np.concatenate(all_labels)
    
    return all_samples, all_labels

# Prepare the full dataset into features and labels
X, y = preprocess_dataset(train_data)  # Assuming train_data contains both train and test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=48)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import svm

# Create an SVM model with a pipeline that includes scaling
model_svm = make_pipeline(
    StandardScaler(),
    svm.SVC(kernel='rbf', random_state=84)
)

# Train the model
model_svm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(random_state=84))])

# %%
accuracy = model_svm.score(X_test, y_test)
print(f'Test accuracy: {accuracy}')
# Out:
# Test accuracy: 0.8888888888888888

# %%
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Predict with the model
y_pred = model_svm.predict(X_test)

# Calculate metrics
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)
f1 = metrics.f1_score(y_test, y_pred)

# Print the metrics
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# Plotting the confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d")
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
# Out:
# Accuracy: 0.8888888888888888
# Precision: 0.902676399026764
# Recall: 0.9636363636363636
# F1 Score: 0.9321608040201006
